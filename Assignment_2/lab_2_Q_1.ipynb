# %%
# Install required packages
# !pip install visual-automata
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 87.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 26.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 7.5 MB/s eta 0:00:00
# ...

# %%
from automata.fa.dfa import DFA
from visual_automata.fa.dfa import VisualDFA

# %%
import string
lower = list(string.ascii_lowercase)
upper = list(string.ascii_uppercase)
input_symbols = set(lower + upper)

all_ascii = set(chr(i) for i in range(32, 127))

invalid_inputs = all_ascii - input_symbols

# %%
transitions = {
    'q0': {},
    'q1': {},
    'q2': {},
    'qReject': {}
}

for c in lower + upper:
    transitions['q0'][c] = 'q1'

for c in lower:
    transitions['q1'][c] = 'q2'

for c in lower:
    transitions['q2'][c] = 'q2'

for state in ['q0', 'q1', 'q2']:
    for c in invalid_inputs:
        transitions[state][c] = 'qReject'

for c in upper:
    transitions['q1'][c] = 'qReject'
    transitions['q2'][c] = 'qReject'

transitions['qReject'] = {c: 'qReject' for c in all_ascii}

# %%
dfa = VisualDFA(
    states={'q0', 'q1', 'q2', 'qReject'},
    input_symbols=all_ascii,
    transitions=transitions,
    initial_state='q0',
    final_states={'q1', 'q2'}
)

# %%
dfa.table
# Out:
#                         !        "        #        $        %        &  \
# →q0      qReject  qReject  qReject  qReject  qReject  qReject  qReject
# *q1      qReject  qReject  qReject  qReject  qReject  qReject  qReject
# *q2      qReject  qReject  qReject  qReject  qReject  qReject  qReject
# qReject  qReject  qReject  qReject  qReject  qReject  qReject  qReject
#
#                '        (        )  ...        u        v        w        x  \
# →q0      qReject  qReject  qReject  ...      *q1      *q1      *q1      *q1
# *q1      qReject  qReject  qReject  ...      *q2      *q2      *q2      *q2
# *q2      qReject  qReject  qReject  ...      *q2      *q2      *q2      *q2
# qReject  qReject  qReject  qReject  ...  qReject  qReject  qReject  qReject
#
#                y        z        {        |        }        ~
# →q0          *q1      *q1  qReject  qReject  qReject  qReject
# *q1          *q2      *q2  qReject  qReject  qReject  qReject
# ...

# %%
dfa.input_check("elephant")
# Out:
#           [Accepted]
# Step: Current state: Input symbol: New state:
# 1                →q0             e        *q1
# 2                *q1             l        *q2
# 3                *q2             e        *q2
# 4                *q2             p        *q2
# 5                *q2             h        *q2
# 6                *q2             a        *q2
# 7                *q2             n        *q2
# 8                *q2             t        *q2
